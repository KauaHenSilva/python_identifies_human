# %%
# requisites cv2 and matplotlib
# %pip install opencv-python-headless
# %pip install matplotlib

# %%
# Get image nana from the web
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/data/lena.jpg

# Get haarcascade for face detection
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Out:
# --2024-06-12 18:36:13--  https://raw.githubusercontent.com/opencv/opencv/master/samples/data/lena.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 91814 (90K) [image/jpeg]
# Saving to: ‘lena.jpg’
#
# lena.jpg            100%[===================>]  89.66K  --.-KB/s    in 0.03s
#
# 2024-06-12 18:36:14 (3.49 MB/s) - ‘lena.jpg’ saved [91814/91814]
#
# --2024-06-12 18:36:14--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal 100%[===================>] 908.33K  5.88MB/s    in 0.2s
#
# 2024-06-12 18:36:15 (5.88 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [930127/930127]

# %%
# Import the necessary libraries

import cv2
import matplotlib.pyplot as plt

# %%
# Load image

img = cv2.imread('lena.jpg')

imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imgGray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# laod haarcascade

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
# Detect faces

detec = face_cascade.detectMultiScale(imgGray, 1.1, 4)

# Draw rectangles

for x, y, h, w in detec:
    cv2.rectangle(imgRGB, (x, y), (x+w, y+h), (0, 255, 0), 3)

# Show image

plt.imshow(imgRGB)
