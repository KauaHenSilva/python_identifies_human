# %%
# requisites cv2 and matplotlib
# %pip install opencv-python
# %pip install matplotlib

# get the image
# !wget https://st2.depositphotos.com/3591429/5246/i/450/depositphotos_52460201-stock-photo-group-of-people-standing.jpg

# rename the image
# !mv depositphotos_52460201-stock-photo-group-of-people-standing.jpg people.jpg

# get cascade body file
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_fullbody.xml

# %%
# imports

import cv2
import matplotlib.pyplot as plt

# %%
# load the image

image = cv2.imread('people.jpg')

imgRGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
imgGray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# detect the bodies

body_cascade = cv2.CascadeClassifier('haarcascade_fullbody.xml')
bodies = body_cascade.detectMultiScale(imgGray, 1.001, 5, minSize=(70, 70))

# draw the rectangles

for (x, y, w, h) in bodies:
    cv2.rectangle(imgRGB, (x, y), (x+w, y+h), (0, 255, 0), 2)

# show the image

plt.imshow(imgRGB)
