# %%
# requisites cv2 and matplotlib
# %pip install opencv-python-headless
# %pip install matplotlib

# Get image nana from the web
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/data/lena.jpg

# Get haarcascade for face detection
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('lena.jpg')

imgGray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
eyes = eye_cascade.detectMultiScale(imgGray, 1.1, 4)

for (x, y, w, h) in eyes:
    cv2.rectangle(imgRGB, (x, y), (x+w, y+h), (255, 0, 0), 2)

plt.imshow(imgRGB)
